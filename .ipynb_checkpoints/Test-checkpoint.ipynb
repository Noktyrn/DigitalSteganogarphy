# %%
import os
from Utils.utils import custom_plot
from Utils.StegoSet import StegoSet
from os import listdir
from os.path import isfile, join
from Algorithms.PM1 import insert_message_PM1, extract_message_PM1
from Algorithms.iPM1 import insert_message_iPM1
from Algorithms.StegoAlgorithm import StegoAlgorithm as algo
from Utils.Experimenter import Experimenter
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e600f9033c28> in <module>
#       5 from os.path import isfile, join
#       6 from Algorithms.PM1 import insert_message_PM1, extract_message_PM1
# ----> 7 from Algorithms.iPM1 import insert_message_iPM1
#       8 from Algorithms.StegoAlgorithm import StegoAlgorithm as algo
#       9 from Utils.Experimenter import Experimenter
#
# ~/Desktop/DigitalSteganography/experiments/Algorithms/iPM1.py in <module>
#       5 from skimage.metrics import structural_similarity as ssim
#       6 from numpy.random import randint
# ----> 7 from PM1 import extract_message_PM1, insert_message_PM1
#       8
#       9 def get_block_indexes_structure_from_route(route):
#
# ModuleNotFoundError: No module named 'PM1'

# %%
import sys
print(sys.path)
# Out:
# ['/Users/tagirrakipov/Desktop/DigitalSteganography/experiments', '/opt/anaconda3/lib/python38.zip', '/opt/anaconda3/lib/python3.8', '/opt/anaconda3/lib/python3.8/lib-dynload', '', '/Users/tagirrakipov/.local/lib/python3.8/site-packages', '/opt/anaconda3/lib/python3.8/site-packages', '/opt/anaconda3/lib/python3.8/site-packages/aeosa', '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/Users/tagirrakipov/.ipython', '..', '..']

# %%
mypath = os.getcwd() + "/images/grey/"
onlyfiles = [mypath + f for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfiles.remove(mypath + '.DS_Store')

my_set = StegoSet(onlyfiles[:1], init_way='files')

# %%
for i in my_set:
    print(i.shape)
# Out:
# (512, 512)

# %%
PM1 = algo(insert_message_iPM1, extract_message_PM1)
exp = Experimenter(my_set, PM1)
exp.make_experiment()
# Out:
# 15384
# 30769
# 46153
# 61537
# 76922
# 92306
# 107690
# 123074
# 138459
# 153843

# %%
x_vals = exp.percentages

data = {'PSNR': exp.psnr_vals, 'SSIM': exp.ssim_vals, 'BER': exp.ber_vals, 'TIME': exp.time_vals}

for d in data:
    plt.figure(figsize=(10, 5))
    custom_plot(x_vals, data[d])
    
    plt.xlabel('Container fill rate, 100% = 154k bits')
    plt.ylabel('Parameter value')
    plt.xticks(x_vals, rotation = 70)
    plt.title(d)
    
    plt.show()
